# %%
import pandas as pd
import os, sys



file_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.dirname(file_dir)
newPath = os.path.join(parent_dir, 'data/db_historic/rt_leavetimes_2016_I_DB.txt')

# %%
# use chunk size

chunk_size = 1000000
count=1
suppressedIsOneCount=0

# load the big file in smaller chunks
for leave_chunk in pd.read_csv(newPath, usecols=['dayofservice','tripid','progrnumber','stoppointid', 'plannedtime_arr','plannedtime_dep','actualtime_arr','actualtime_dep','suppressed'], delimiter=';', chunksize=chunk_size):
    leave_chunk = leave_chunk[leave_chunk.suppressed != 1]
    print("------------------------")
    print("CHUNK number: ", count)
    print()
    suppressed_is_1 = leave_chunk['suppressed']==1  
    is_suppressed = leave_chunk[suppressed_is_1]
    print("Number of rows in this chunk where suppressed column has value 1: ", is_suppressed.shape[0])
    print()
    # change datatype of dayofservice from string to datetime format
    leave_chunk['dayofservice'] =  pd.to_datetime(leave_chunk['dayofservice'], dayfirst=True)
    leave_chunk.to_csv('leave16.csv', index=False, header=False, mode='a')  
    suppressedIsOneCount=suppressedIsOneCount+is_suppressed.shape[0]
    count=count+1
    print("FINISHED A CHUNK")
    #if count==2:
     #   break
        
        

print()
print("Final total of 'suppressed=1' values: ", suppressedIsOneCount)
print()
print("CELL FINISHED")
# Out:
# ------------------------
# CHUNK number:  1
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  2
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  3
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  4
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  5
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  6
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  7
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  8
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  9
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  10
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  11
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  12
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  13
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  14
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  15
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  16
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  17
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  18
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  19
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  20
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  21
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  22
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  23
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  24
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  25
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  26
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  27
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  28
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  29
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  30
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  31
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  32
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  33
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  34
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  35
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  36
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  37
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  38
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  39
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  40
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  41
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  42
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  43
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  44
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  45
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  46
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  47
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  48
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  49
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  50
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  51
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  52
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  53
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  54
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  55
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  56
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  57
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  58
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
# ------------------------
# CHUNK number:  59
#
# Number of rows in this chunk where suppressed column has value 1:  0
#
# FINISHED A CHUNK
#
# Final total of 'suppressed=1' values:  0
#
# CELL FINISHED

# %% [markdown]
# This creates a csv file with 56843319 lines, (ie of the original 58923405 lines in the .txt file,  2,080,086 'suppressed = 1' rows were dropped)
